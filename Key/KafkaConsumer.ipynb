# %%
pip install s3fs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from kafka import KafkaConsumer
from time import sleep
from json import loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test_new',
    bootstrap_servers=['3.16.162.213:9092'],
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
# for c in consumer:
#     print(c.value)
# Out:
# {'Index': 'TWII', 'Date': '2004-01-07', 'Open': 6174.950195, 'High': 6215.450195, 'Low': 6130.350098, 'Close': 6141.25, 'Adj Close': 6141.227539, 'Volume': 6273600.0, 'CloseUSD': 245.65}
# {'Index': 'SSMI', 'Date': '2007-12-12', 'Open': 8745.700195, 'High': 8918.799805, 'Low': 8722.5, 'Close': 8852.299805, 'Adj Close': 8852.299805, 'Volume': 102151100.0, 'CloseUSD': 9826.052783550002}
# {'Index': '399001.SZ', 'Date': '2010-08-31', 'Open': 11273.86035, 'High': 11377.70996, 'Low': 11237.09961, 'Close': 11338.70996, 'Adj Close': 11338.58301, 'Volume': 107800.0, 'CloseUSD': 1814.1935936}
# {'Index': 'IXIC', 'Date': '1979-12-04', 'Open': 144.800003, 'High': 144.800003, 'Low': 144.800003, 'Close': 144.800003, 'Adj Close': 144.800003, 'Volume': 0.0, 'CloseUSD': 144.800003}
# {'Index': 'TWII', 'Date': '2017-06-20', 'Open': 10286.79004, 'High': 10354.37012, 'Low': 10286.79004, 'Close': 10324.45996, 'Adj Close': 10324.45996, 'Volume': 1913800.0, 'CloseUSD': 412.9783984}
# ...

# %%
# Create the object
s3 = S3FileSystem()

# %%
# For each row we want to create a file and store it on S3 bucket but we also want to give the file unique every time
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-proj-lx/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # For each row we want to create a file and store it on S3 bucket but we also want to give the file unique every time
# ----> 2 for count, i in enumerate(consumer):
#       3     with s3.open("s3://kafka-proj-lx/stock_market_{}.json".format(count), 'w') as file:
#       4         json.dump(i.value, file)
#
# File /opt/homebrew/lib/python3.11/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /opt/homebrew/lib/python3.11/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# ...
